# %% [markdown]
# <a href="https://colab.research.google.com/github/ChanikyaMysur/CSA6301_ThreatIntelligenceAndNetworkSecurity/blob/main/lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from cryptography.fernet import Fernet

# Generate a shared secret key
key = Fernet.generate_key()

# Sender and receiver use the same key
cipher = Fernet(key)

message = input("Enter message to send: ")

# Encrypt
encrypted_message = cipher.encrypt(message.encode())

print("\nEncrypted Message:")
print(encrypted_message)

# Decrypt
decrypted_message = cipher.decrypt(encrypted_message).decode()

print("\nDecrypted Message:")
print(decrypted_message)
# Out:
# Enter message to send: Hi Chan
#
# Encrypted Message:
# b'gAAAAABqaxbp2YQNHkB54EWILh882-iXU_6o_Rv8R0RjtCJTsQcH0MvZP2nVaYtGlqZyJs_wVqEpW4D6ScYHO1VcRB_XON9caA=='
#
# Decrypted Message:
# Hi Chan
